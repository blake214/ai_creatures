# %%
import pandas as pd

# %% [markdown]
# ---
# #### Crossover

# %%
df_record = pd.read_csv('crossover_1.csv', header=None, sep=',')

# %%
df_record.drop([3], axis=1, inplace=True)
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
df_1_mean_mean = df_1.mean(axis=0).iloc[1]
df_1_ratio = df_1_mean_mean / df_1_mean_fittest * 100

df_2_mean_fittest = df_2.mean(axis=0).iloc[0]
df_2_mean_mean = df_2.mean(axis=0).iloc[1]
df_2_ratio = df_2_mean_mean / df_2_mean_fittest * 100

print("DF_1","\n","fittest:",df_1_mean_fittest,"\n", "mean:",df_1_mean_mean,"\n", "ratio:",df_1_ratio)
print("DF_2","\n","fittest:",df_2_mean_fittest,"\n", "mean:",df_2_mean_mean,"\n", "ratio:",df_2_ratio)
# Out:
# DF_1
#  fittest: 8.785117999999999
#  mean: 3.5846039999999997
#  ratio: 40.803140037504335
# DF_2
#  fittest: 6.880059999999999
#  mean: 2.67419
#  ratio: 38.86870172643843
# /tmp/ipykernel_80240/1636355623.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
# /tmp/ipykernel_80240/1636355623.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_mean = df_1.mean(axis=0).iloc[1]
# ...

# %% [markdown]
# ---
# #### Mutation Rate

# %%
df_record = pd.read_csv('mutation_rate_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ad'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ae'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ad'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ae'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ad'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ae'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

df_4 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ab'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ac'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ae'].index)
df_4 = df_4.reset_index()
df_4.drop(['index'], axis=1, inplace=True)

df_5 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ab'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ac'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ad'].index)
df_5 = df_5.reset_index()
df_5.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >

# %%
df_4.plot()
# Out:
# <AxesSubplot: >

# %%
df_5.plot()
# Out:
# <AxesSubplot: >

# %%
df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
df_1_mean_mean = df_1.mean(axis=0).iloc[1]
df_1_ratio = df_1_mean_mean / df_1_mean_fittest * 100

df_2_mean_fittest = df_2.mean(axis=0).iloc[0]
df_2_mean_mean = df_2.mean(axis=0).iloc[1]
df_2_ratio = df_2_mean_mean / df_2_mean_fittest * 100

df_3_mean_fittest = df_3.mean(axis=0).iloc[0]
df_3_mean_mean = df_3.mean(axis=0).iloc[1]
df_3_ratio = df_3_mean_mean / df_3_mean_fittest * 100

df_4_mean_fittest = df_4.mean(axis=0).iloc[0]
df_4_mean_mean = df_4.mean(axis=0).iloc[1]
df_4_ratio = df_4_mean_mean / df_4_mean_fittest * 100

df_5_mean_fittest = df_5.mean(axis=0).iloc[0]
df_5_mean_mean = df_5.mean(axis=0).iloc[1]
df_5_ratio = df_5_mean_mean / df_5_mean_fittest * 100

print("DF_1","\n","fittest:",df_1_mean_fittest,"\n", "mean:",df_1_mean_mean,"\n", "ratio:",df_1_ratio)
print("DF_2","\n","fittest:",df_2_mean_fittest,"\n", "mean:",df_2_mean_mean,"\n", "ratio:",df_2_ratio)
print("DF_3","\n","fittest:",df_3_mean_fittest,"\n", "mean:",df_3_mean_mean,"\n", "ratio:",df_3_ratio)
print("DF_4","\n","fittest:",df_4_mean_fittest,"\n", "mean:",df_4_mean_mean,"\n", "ratio:",df_4_ratio)
print("DF_5","\n","fittest:",df_5_mean_fittest,"\n", "mean:",df_5_mean_mean,"\n", "ratio:",df_5_ratio)
# Out:
# DF_1
#  fittest: 7.402106
#  mean: 2.9999279999999997
#  ratio: 40.528033508301554
# DF_2
#  fittest: 7.316858
#  mean: 2.913538
#  ratio: 39.81952362612476
# DF_3
#  fittest: 7.798764000000001
#  mean: 2.482634
#  ratio: 31.833685440410807
# DF_4
#  fittest: 7.494194
#  mean: 2.2409120000000002
#  ratio: 29.901974782077968
# DF_5
#  fittest: 8.422187999999998
#  mean: 2.1066700000000003
#  ratio: 25.01333382726675
# /tmp/ipykernel_80240/2852402876.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
# ...

# %% [markdown]
# ---
# #### Mutation Amount

# %%
df_record = pd.read_csv('mutation_amount_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ad'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ad'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ad'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

df_4 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ab'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ac'].index)
df_4 = df_4.reset_index()
df_4.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >

# %%
df_4.plot()
# Out:
# <AxesSubplot: >

# %%
df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
df_1_mean_mean = df_1.mean(axis=0).iloc[1]
df_1_ratio = df_1_mean_mean / df_1_mean_fittest * 100

df_2_mean_fittest = df_2.mean(axis=0).iloc[0]
df_2_mean_mean = df_2.mean(axis=0).iloc[1]
df_2_ratio = df_2_mean_mean / df_2_mean_fittest * 100

df_3_mean_fittest = df_3.mean(axis=0).iloc[0]
df_3_mean_mean = df_3.mean(axis=0).iloc[1]
df_3_ratio = df_3_mean_mean / df_3_mean_fittest * 100

df_4_mean_fittest = df_4.mean(axis=0).iloc[0]
df_4_mean_mean = df_4.mean(axis=0).iloc[1]
df_4_ratio = df_4_mean_mean / df_4_mean_fittest * 100

print("DF_1","\n","fittest:",df_1_mean_fittest,"\n", "mean:",df_1_mean_mean,"\n", "ratio:",df_1_ratio)
print("DF_2","\n","fittest:",df_2_mean_fittest,"\n", "mean:",df_2_mean_mean,"\n", "ratio:",df_2_ratio)
print("DF_3","\n","fittest:",df_3_mean_fittest,"\n", "mean:",df_3_mean_mean,"\n", "ratio:",df_3_ratio)
print("DF_4","\n","fittest:",df_4_mean_fittest,"\n", "mean:",df_4_mean_mean,"\n", "ratio:",df_4_ratio)
# Out:
# DF_1
#  fittest: 6.9362520000000005
#  mean: 2.705768
#  ratio: 39.00907867822564
# DF_2
#  fittest: 7.732429999999999
#  mean: 2.8002459999999996
#  ratio: 36.21430779198777
# DF_3
#  fittest: 7.783378000000001
#  mean: 2.5537560000000004
#  ratio: 32.81038130230859
# DF_4
#  fittest: 9.178906000000001
#  mean: 2.796128
#  ratio: 30.46254096076373
# /tmp/ipykernel_80240/2918185108.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
# ...

# %% [markdown]
# ---
# #### Grow Shrink rate

# %%
df_record = pd.read_csv('grow_shrink_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ad'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ae'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ad'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ae'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ad'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ae'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

df_4 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ab'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ac'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ae'].index)
df_4 = df_4.reset_index()
df_4.drop(['index'], axis=1, inplace=True)

df_5 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ab'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ac'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ad'].index)
df_5 = df_5.reset_index()
df_5.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >

# %%
df_4.plot()
# Out:
# <AxesSubplot: >

# %%
df_5.plot()
# Out:
# <AxesSubplot: >

# %%
df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
df_1_mean_mean = df_1.mean(axis=0).iloc[1]
df_1_ratio = df_1_mean_mean / df_1_mean_fittest * 100

df_2_mean_fittest = df_2.mean(axis=0).iloc[0]
df_2_mean_mean = df_2.mean(axis=0).iloc[1]
df_2_ratio = df_2_mean_mean / df_2_mean_fittest * 100

df_3_mean_fittest = df_3.mean(axis=0).iloc[0]
df_3_mean_mean = df_3.mean(axis=0).iloc[1]
df_3_ratio = df_3_mean_mean / df_3_mean_fittest * 100

df_4_mean_fittest = df_4.mean(axis=0).iloc[0]
df_4_mean_mean = df_4.mean(axis=0).iloc[1]
df_4_ratio = df_4_mean_mean / df_4_mean_fittest * 100

df_5_mean_fittest = df_5.mean(axis=0).iloc[0]
df_5_mean_mean = df_5.mean(axis=0).iloc[1]
df_5_ratio = df_5_mean_mean / df_5_mean_fittest * 100

print("DF_1","\n","fittest:",df_1_mean_fittest,"\n", "mean:",df_1_mean_mean,"\n", "ratio:",df_1_ratio)
print("DF_2","\n","fittest:",df_2_mean_fittest,"\n", "mean:",df_2_mean_mean,"\n", "ratio:",df_2_ratio)
print("DF_3","\n","fittest:",df_3_mean_fittest,"\n", "mean:",df_3_mean_mean,"\n", "ratio:",df_3_ratio)
print("DF_4","\n","fittest:",df_4_mean_fittest,"\n", "mean:",df_4_mean_mean,"\n", "ratio:",df_4_ratio)
print("DF_5","\n","fittest:",df_5_mean_fittest,"\n", "mean:",df_5_mean_mean,"\n", "ratio:",df_5_ratio)
# Out:
# DF_1
#  fittest: 8.150038
#  mean: 2.696096
#  ratio: 33.080778273671854
# DF_2
#  fittest: 8.133422
#  mean: 2.51067
#  ratio: 30.868556924748287
# DF_3
#  fittest: 8.013814
#  mean: 2.3788720000000003
#  ratio: 29.684642044349925
# DF_4
#  fittest: 7.558301999999999
#  mean: 2.2957979999999996
#  ratio: 30.374520626458164
# DF_5
#  fittest: 7.099522000000001
#  mean: 2.276048
#  ratio: 32.05917243442586
# /tmp/ipykernel_80240/2852402876.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
# ...

# %% [markdown]
# ---
# #### Population size

# %%
df_record = pd.read_csv('pop_size_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ad'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ae'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ad'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ae'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ad'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ae'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

df_4 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ab'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ac'].index)
df_4 = df_4.drop(df_record[df_record[0] == 'ae'].index)
df_4 = df_4.reset_index()
df_4.drop(['index'], axis=1, inplace=True)

df_5 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ab'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ac'].index)
df_5 = df_5.drop(df_record[df_record[0] == 'ad'].index)
df_5 = df_5.reset_index()
df_5.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >

# %%
df_4.plot()
# Out:
# <AxesSubplot: >

# %%
df_5.plot()
# Out:
# <AxesSubplot: >

# %%
df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
df_1_mean_mean = df_1.mean(axis=0).iloc[1]
df_1_ratio = df_1_mean_mean / df_1_mean_fittest * 100

df_2_mean_fittest = df_2.mean(axis=0).iloc[0]
df_2_mean_mean = df_2.mean(axis=0).iloc[1]
df_2_ratio = df_2_mean_mean / df_2_mean_fittest * 100

df_3_mean_fittest = df_3.mean(axis=0).iloc[0]
df_3_mean_mean = df_3.mean(axis=0).iloc[1]
df_3_ratio = df_3_mean_mean / df_3_mean_fittest * 100

df_4_mean_fittest = df_4.mean(axis=0).iloc[0]
df_4_mean_mean = df_4.mean(axis=0).iloc[1]
df_4_ratio = df_4_mean_mean / df_4_mean_fittest * 100

df_5_mean_fittest = df_5.mean(axis=0).iloc[0]
df_5_mean_mean = df_5.mean(axis=0).iloc[1]
df_5_ratio = df_5_mean_mean / df_5_mean_fittest * 100

print("DF_1","\n","fittest:",df_1_mean_fittest,"\n", "mean:",df_1_mean_mean,"\n", "ratio:",df_1_ratio)
print("DF_2","\n","fittest:",df_2_mean_fittest,"\n", "mean:",df_2_mean_mean,"\n", "ratio:",df_2_ratio)
print("DF_3","\n","fittest:",df_3_mean_fittest,"\n", "mean:",df_3_mean_mean,"\n", "ratio:",df_3_ratio)
print("DF_4","\n","fittest:",df_4_mean_fittest,"\n", "mean:",df_4_mean_mean,"\n", "ratio:",df_4_ratio)
print("DF_5","\n","fittest:",df_5_mean_fittest,"\n", "mean:",df_5_mean_mean,"\n", "ratio:",df_5_ratio)
# Out:
# DF_1
#  fittest: 5.73476
#  mean: 2.7652520000000003
#  ratio: 48.21914081844751
# DF_2
#  fittest: 7.623416
#  mean: 3.2183539999999997
#  ratio: 42.21669131003738
# DF_3
#  fittest: 7.895072
#  mean: 2.691082
#  ratio: 34.085591619683775
# DF_4
#  fittest: 9.284882
#  mean: 3.098168
#  ratio: 33.367876942324095
# DF_5
#  fittest: 9.684700000000001
#  mean: 3.1323220000000003
#  ratio: 32.3429946203806
# /tmp/ipykernel_80240/2852402876.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
# ...

# %% [markdown]
# ---
# #### Generation size

# %%
df_record = pd.read_csv('gen_size_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >

# %%
df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
df_1_mean_mean = df_1.mean(axis=0).iloc[1]
df_1_ratio = df_1_mean_mean / df_1_mean_fittest * 100

df_2_mean_fittest = df_2.mean(axis=0).iloc[0]
df_2_mean_mean = df_2.mean(axis=0).iloc[1]
df_2_ratio = df_2_mean_mean / df_2_mean_fittest * 100

df_3_mean_fittest = df_3.mean(axis=0).iloc[0]
df_3_mean_mean = df_3.mean(axis=0).iloc[1]
df_3_ratio = df_3_mean_mean / df_3_mean_fittest * 100

print("DF_1","\n","fittest:",df_1_mean_fittest,"\n", "mean:",df_1_mean_mean,"\n", "ratio:",df_1_ratio)
print("DF_2","\n","fittest:",df_2_mean_fittest,"\n", "mean:",df_2_mean_mean,"\n", "ratio:",df_2_ratio)
print("DF_3","\n","fittest:",df_3_mean_fittest,"\n", "mean:",df_3_mean_mean,"\n", "ratio:",df_3_ratio)
# Out:
# DF_1
#  fittest: 7.427368
#  mean: 3.00949
#  ratio: 40.51892945118647
# DF_2
#  fittest: 8.7408532
#  mean: 3.2373476
#  ratio: 37.03697483444751
# DF_3
#  fittest: 9.705262199999998
#  mean: 3.1749617999999997
#  ratio: 32.71381787088658
# /tmp/ipykernel_80240/3008349671.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_fittest = df_1.mean(axis=0).iloc[0]
# /tmp/ipykernel_80240/3008349671.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1_mean_mean = df_1.mean(axis=0).iloc[1]
# ...

# %% [markdown]
# ---
# ---
# #### Genome Change : Link Lengths
#
# [[0-2], [0-4], [0-6]]

# %%
df_record = pd.read_csv('Geno_link_length_a_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)
df_record.drop([2], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ---
# #### Genome Change : Link Spaces
#
# [[0-1], [0-3], [0-5]]

# %%
df_record = pd.read_csv('Geno_link_space_a_1.csv', header=None, sep=',')
df_record.drop([3], axis=1, inplace=True)
df_record.drop([2], axis=1, inplace=True)

# %%
df_1 = df_record.drop(df_record[df_record[0] == 'ab'].index)
df_1 = df_1.drop(df_1[df_1[0] == 'ac'].index)
df_1 = df_1.reset_index()
df_1.drop(['index'], axis=1, inplace=True)

df_2 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_2 = df_2.drop(df_2[df_2[0] == 'ac'].index)
df_2 = df_2.reset_index()
df_2.drop(['index'], axis=1, inplace=True)

df_3 = df_record.drop(df_record[df_record[0] == 'aa'].index)
df_3 = df_3.drop(df_record[df_record[0] == 'ab'].index)
df_3 = df_3.reset_index()
df_3.drop(['index'], axis=1, inplace=True)

# %%
df_1.plot()
# Out:
# <AxesSubplot: >

# %%
df_2.plot()
# Out:
# <AxesSubplot: >

# %%
df_3.plot()
# Out:
# <AxesSubplot: >
